# %%
import cynet as cn
import pandas as pd
import numpy as np

# %%
_log_file='../../backup/crime_log_small.csv'

# %%
df = pd.read_csv(_log_file,parse_dates=True)

# %%
max(df["Latitude"])
# Out:
# 42.005446228000004

# %%
min(df["Latitude"])
# Out:
# 41.654719640000003

# %%
max(df["Longitude"])
# Out:
# -87.538903650999998

# %%
min(df["Longitude"])
# Out:
# -87.805606689000001

# %%
EPS=0.03
grid={'Latitude':np.arange(41.5,42,EPS),
      'Longitude':np.arange(-87.8,-87.5,EPS),
      'Eps':EPS}

# %%
min(df['Date'])
# Out:
# '05/05/2011 09:00:00 AM'

# %%
max(df['Date'])
# Out:
# '10/20/2011 12:01:00 AM'

# %%
S=cn.spatioTemporal(log_file=_log_file,
                    types=[['BURGLARY','THEFT'],['HOMICIDE']],
                    value_limits=None,
                    grid=grid,
                    init_date='05/05/2011',
                    end_date='10/21/2011',
                    freq='12h',
                    threshold=0.05)

# %%
S.fit(csvPREF='TScrime',auto_adjust_time=True,max_incr=48)
# Out:
# ...
#  50%|█████     | 5/10 [00:00<00:00, 44.42it/s]
# [('6H', 0.0), ('12H', 0.0), ('18H', 0.0), ('24H', 0.0), ('30H', 0.0), ('36H', 0.0), ('42H', 0.0), ('48H', 0.0)]
# Optimal frequency: 48H
# ...
#  40%|████      | 4/10 [00:00<00:00, 38.27it/s]
# [('6H', 0.0), ('12H', 0.0), ('18H', 0.0), ('24H', 0.0), ('30H', 0.0), ('36H', 0.0), ('42H', 0.0), ('48H', 0.0)]
# Optimal frequency: 48H
# ...
# 100%|██████████| 17/17 [00:04<00:00,  3.49it/s]

# %%
len(grid["Latitude"])
# Out:
# 17

# %%
len(grid["Longitude"])
# Out:
# 100

# %%
len(grid["Latitude"]) == len(grid["Longitude"])
len(grid["Latitude"])
# Out:
# 100

# %%
min(len(grid["Latitude"]), len(grid["Longitude"]))
# Out:
# 100

# %%
stop = False
indices = range(min(len(grid["Latitude"]), len(grid["Longitude"])))
EPS=grid["Eps"]
_types=['BURGLARY','THEFT']

while not stop:
    index = random.choice(indices)
    i = grid["Latitude"][index]
    j = grid["Longitude"][index]
    
    tile = [i, i + EPS, j, j + EPS]

    TS_NAME = ('#'.join(str(x) for x in tile))
    lat_ = tile[0:2]
    lon_ = tile[2:4]

    test = df.loc[(df["Latitude"] > lat_[0])
                & (df["Latitude"] <= lat_[1])
                & (df["Longitude"] > lon_[0])
                & (df["Longitude"] <= lon_[1])]
    print(test)
    if test.shape[0] > 0:
        stop = True
# Out:
# Empty DataFrame
# Columns: [ID, Case Number, Date, Block, IUCR, Primary Type, Description, Location Description, Arrest, Domestic, Beat, District, Ward, Community Area, FBI Code, X Coordinate, Y Coordinate, Year, Updated On, Latitude, Longitude, Location]
# Index: []
#
# [0 rows x 22 columns]
# Empty DataFrame
# Columns: [ID, Case Number, Date, Block, IUCR, Primary Type, Description, Location Description, Arrest, Domestic, Beat, District, Ward, Community Area, FBI Code, X Coordinate, Y Coordinate, Year, Updated On, Latitude, Longitude, Location]
# Index: []
#
# [0 rows x 22 columns]
#          ID Case Number                    Date               Block  IUCR  \
# 44  8316899    HT550695  10/20/2011 05:30:00 AM  122XX S HALSTED ST  1310
#
#        Primary Type  Description     Location Description  Arrest  Domestic  \
# 44  CRIMINAL DAMAGE  TO PROPERTY  RESIDENCE PORCH/HALLWAY   False     False
#
#                 ...                Ward  Community Area  FBI Code  \
# ...

# %%
index = random.choice(indices)
grid["Latitude"][index]
# Out:
# 41.545000000000002

# %%
import random

# %%
EPS
# Out:
# 0.003

# %%
grid["Eps"]
# Out:
# 0.003

# %%
def stringify(List):
    """
    Utility function
    @author zed.uchicago.edu

    Converts list into string separated by dashes
             or empty string if input list
             is not list or is empty

    Input:
        List (list): input list to be converted

    Output:
        (string)
    """
    if List is None:
        return ''
    if not List:
        return ''

# %%
index = 9
lat_= [grid["Latitude"][index], grid["Latitude"][index]+grid["Eps"]]
lat_= [grid["Longitude"][index], grid["Longitude"][index]+grid["Eps"]]

df.loc[(df["Latitude"] > lat_[0])
                & (df["Latitude"] <= lat_[1])
                & (df["Longitude"] > lon_[0])
                & (df["Longitude"] <= lon_[1])]
# Out:
# Empty DataFrame
# Columns: [ID, Case Number, Date, Block, IUCR, Primary Type, Description, Location Description, Arrest, Domestic, Beat, District, Ward, Community Area, FBI Code, X Coordinate, Y Coordinate, Year, Updated On, Latitude, Longitude, Location]
# Index: []
#
# [0 rows x 22 columns]

# %%
grid["Eps"] = 0.03

# %%
grid["Eps"]
# Out:
# 0.03

# %%
df
# Out:
#          ID Case Number                    Date                     Block  \
# 0   8316800    HT550945  08/11/2011 11:00:00 AM     086XX S MARQUETTE AVE
# 1   8316805    HT550781  10/20/2011 05:00:00 AM       056XX S ABERDEEN ST
# 2   8316806    HT550706  10/20/2011 05:45:00 AM       079XX S LOOMIS BLVD
# 3   8316811    HT539324  10/12/2011 12:23:52 PM           003XX E 75TH ST
# 4   8316814    HT551005  10/20/2011 10:40:00 AM      103XX S ELIZABETH ST
# 5   8316821    HT551028  10/20/2011 10:50:00 AM      040XX W VAN BUREN ST
# 6   8316822    HT551031  10/19/2011 02:00:00 AM       071XX W DICKENS AVE
# 7   8316824    HT551032  10/20/2011 12:00:00 AM       034XX N NATCHEZ AVE
# 8   8316825    HT549690  10/19/2011 12:51:00 PM            079XX S ADA ST
# 9   8316826    HT549865  10/19/2011 06:00:00 AM    011XX N LEAMINGTON AVE
# 10  8316827    HT550963  09/01/2011 04:00:00 PM       079XX S LOOMIS BLVD
# 11  8316838    HT548010  10/17/2011 03:20:00 PM        055XX N KEDZIE AVE
# ...

# %%
len(grid["Latitude"])
# Out:
# 17

# %%
len(grid["Longitude"])
# Out:
# 10
